# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
TC= pd.read_csv("GlobalLandTemperaturesByCountry.csv", encoding='ISO-8859-1')
TC=TC.dropna()
TC['dt'] = pd.to_datetime(TC['dt'])
TC=TC.drop(TC[TC['dt'] < "1960-01-01" ].index)
TC.set_index("dt", inplace=True)
print(TC)
# Out:
#             AverageTemperature  AverageTemperatureUncertainty   Country
# dt
# 1960-01-01              -4.380                          0.430    Ãland
# 1960-02-01              -5.233                          0.382    Ãland
# 1960-03-01              -2.362                          0.638    Ãland
# 1960-04-01               1.922                          0.450    Ãland
# 1960-05-01               8.495                          0.287    Ãland
# ...                        ...                            ...       ...
# 2013-04-01              21.142                          0.495  Zimbabwe
# 2013-05-01              19.059                          1.022  Zimbabwe
# 2013-06-01              17.613                          0.473  Zimbabwe
# 2013-07-01              17.000                          0.453  Zimbabwe
# 2013-08-01              19.759                          0.717  Zimbabwe
#
# [155869 rows x 3 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
countries = TC.index.get_level_values('dt').unique()
unique_countries = TC['Country'].unique()
i=0
def ad_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print("1. ADF : ",dftest[0])
     print("2. P-Value : ", dftest[1])
     print("3. Num Of Lags : ", dftest[2])
     print("4. Num Of Observations Used For ADF Regression:",      dftest[3])
     print("5. Critical Values :")
     i=dftest[2]
     for key, val in dftest[4].items():
         print("\t",key, ": ", val)

# %%
from pmdarima import auto_arima
import warnings
from sklearn.metrics import mean_squared_error
from math import sqrt
for country in unique_countries:
    df=TC[TC["Country"]==country]
    if df.empty:
      continue
    ad_test(df['AverageTemperature'])
    warnings.filterwarnings("ignore")
    stepwise_fit = auto_arima(df['AverageTemperature'], trace=True, suppress_warnings=True)
    stepwise_fit.summary()
    best_model_params = stepwise_fit.get_params()
    order = best_model_params['order']
    train=df.iloc[:-30]
    test=df.iloc[-30:]
    model=ARIMA(train['AverageTemperature'],order=order)
    model=model.fit()
    model.summary()
    start=len(train)
    end=len(train)+len(test)-1
    pred=model.predict(start=start,end=end,typ='levels').rename('ARIMA Predictions')
    pred.index=df.index[start:end+1]
    pred.plot(legend=True)
    plt.clf()
    test['AverageTemperature'].plot(legend=True)
    plt.clf()
    test['AverageTemperature'].mean()
    rmse=sqrt(mean_squared_error(pred,test['AverageTemperature']))
    model2=ARIMA(df['AverageTemperature'],order=order)
    model2=model2.fit()
    index_future_dates=pd.date_range(start='2013-09-01',end='2030-12-01',freq=pd.DateOffset(months=1))
    pred2=model2.predict(start=len(df),end=len(df)+len(index_future_dates)- 1,typ='levels').rename('AverageTemperature')
    pred2.index=index_future_dates
    pred2 = pred2.to_frame()
    pred2["AverageTemperatureUncertainty"]=[rmse for _ in range(len(pred2))]
    pred2["Country"]=[country for _ in range(len(pred2))]
    TC = pd.concat([TC, pred2])
# Out:
# 1. ADF :  -4.425845030121276
# 2. P-Value :  0.00026708357979543995
# 3. Num Of Lags :  14
# 4. Num Of Observations Used For ADF Regression: 629
# 5. Critical Values :
# 	 1% :  -3.4407890899441127
# 	 5% :  -2.8661459340578905
# 	 10% :  -2.5692228868342766
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2842.903, Time=0.71 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4327.377, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3601.039, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3768.933, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4674.067, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3358.350, Time=0.25 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2970.350, Time=0.34 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2906.335, Time=0.83 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=2741.887, Time=0.76 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3300.990, Time=0.30 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=3270.447, Time=0.53 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=2743.266, Time=1.03 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=3770.825, Time=0.62 sec
#
# Best model:  ARIMA(2,0,3)(0,0,0)[0] intercept
# Total fit time: 7.601 seconds
# 1. ADF :  -4.150461768726531
# 2. P-Value :  0.0007983444129377642
# 3. Num Of Lags :  17
# 4. Num Of Observations Used For ADF Regression: 626
# 5. Critical Values :
# 	 1% :  -3.4408393249134326
# 	 5% :  -2.86616806030903
# 	 10% :  -2.569234676071002
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2431.690, Time=0.71 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4685.962, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3860.304, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=4034.987, Time=0.18 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5497.227, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3382.102, Time=0.25 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2667.717, Time=0.43 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2671.179, Time=0.87 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=3538.574, Time=0.26 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3303.994, Time=0.42 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=2600.516, Time=0.77 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=3318.150, Time=0.14 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 6.075 seconds
# 1. ADF :  -3.0830004386015646
# 2. P-Value :  0.027837079113415812
# 3. Num Of Lags :  13
# 4. Num Of Observations Used For ADF Regression: 630
# 5. Critical Values :
# 	 1% :  -3.4407724517110783
# 	 5% :  -2.866138605582151
# 	 10% :  -2.569218982111363
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1568.297, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2021.675, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1775.153, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1747.402, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2019.702, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1654.426, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.13 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1702.160, Time=0.12 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=1572.668, Time=0.23 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1566.327, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1652.448, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1409.881, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1700.178, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1613.106, Time=0.08 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1570.703, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1773.170, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1570.591, Time=0.10 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1413.345, Time=0.54 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 7.179 seconds
# 1. ADF :  -4.472879068672954
# 2. P-Value :  0.0002200600985173436
# 3. Num Of Lags :  17
# 4. Num Of Observations Used For ADF Regression: 626
# 5. Critical Values :
# 	 1% :  -3.4408393249134326
# 	 5% :  -2.86616806030903
# 	 10% :  -2.569234676071002
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4314.955, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3527.089, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3699.429, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5296.691, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=2957.325, Time=0.18 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=2697.611, Time=0.20 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=2549.238, Time=0.27 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=2453.917, Time=0.81 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=2485.833, Time=0.66 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=2450.008, Time=0.90 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=2462.371, Time=1.12 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=2564.449, Time=0.82 sec
#
# Best model:  ARIMA(5,0,1)(0,0,0)[0] intercept
# Total fit time: 7.573 seconds
# 1. ADF :  -3.0107136296853763
# 2. P-Value :  0.03390592321618209
# 3. Num Of Lags :  13
# 4. Num Of Observations Used For ADF Regression: 630
# 5. Critical Values :
# 	 1% :  -3.4407724517110783
# 	 5% :  -2.866138605582151
# 	 10% :  -2.569218982111363
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2266.621, Time=0.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4469.920, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3630.114, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3781.178, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5966.163, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3027.420, Time=0.26 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2292.197, Time=0.61 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2295.576, Time=0.81 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=3239.592, Time=0.28 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=2915.742, Time=0.42 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=2277.024, Time=1.33 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=2985.542, Time=0.24 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 6.987 seconds
# 1. ADF :  -3.0496872916755198
# 2. P-Value :  0.03050762354600764
# 3. Num Of Lags :  20
# 4. Num Of Observations Used For ADF Regression: 623
# 5. Critical Values :
# 	 1% :  -3.440890045708521
# 	 5% :  -2.8661904001753618
# 	 10% :  -2.569246579178572
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=619.530, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=624.696, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=621.083, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=621.382, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=622.696, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=624.510, Time=0.31 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=624.691, Time=0.34 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=618.134, Time=0.84 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=626.692, Time=0.19 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=486.536, Time=0.99 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=426.734, Time=1.07 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=414.286, Time=1.08 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=571.790, Time=0.31 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=621.110, Time=0.22 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=416.374, Time=0.44 sec
#
# Best model:  ARIMA(5,1,1)(0,0,0)[0] intercept
# Total fit time: 7.691 seconds
# 1. ADF :  -4.514800924160512
# 2. P-Value :  0.00018487900762009985
# 3. Num Of Lags :  19
# 4. Num Of Observations Used For ADF Regression: 624
# 5. Critical Values :
# 	 1% :  -3.440873084361836
# 	 5% :  -2.866182929627575
# 	 10% :  -2.5692425987220577
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=2468.756, Time=0.83 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4116.225, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=3373.615, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3541.946, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5147.342, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3083.373, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2625.438, Time=0.65 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=2629.352, Time=1.02 sec

# %%
pred2.to_csv('Temperature_1960_2030.csv', index=True)
